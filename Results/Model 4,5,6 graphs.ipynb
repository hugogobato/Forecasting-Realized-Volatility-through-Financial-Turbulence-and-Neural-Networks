# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import scipy.stats

# %%
df = pd.read_excel('Model 4,5,6 graphs.xlsx')

# %%
df.head()
# Out:
#         Date   Actuals   Model 4   Model 5   Model 6
# 0 2021-11-01  0.003954  0.005979  0.006011  0.005983
# 1 2021-11-02  0.002441  0.003603  0.003672  0.005754
# 2 2021-11-03  0.004960  0.002561  0.002582  0.005291
# 3 2021-11-04  0.002179  0.004922  0.005016  0.005320
# 4 2021-11-05  0.006606  0.002468  0.002416  0.005034

# %% [markdown]
# # Model 4

# %%
plt.plot(df["Date"], df["Actuals"])
plt.plot(df["Date"], df["Model 4"]) 
plt.ylabel("S&P 500 Realized Volatility")
plt.legend(['Actuals', 'Forecasts'])

# %% [markdown]
# # Model 5

# %%
plt.plot(df["Date"], df["Actuals"])
plt.plot(df["Date"], df["Model 5"]) 
plt.ylabel("S&P 500 Realized Volatility")
plt.legend(['Actuals', 'Forecasts'])

# %% [markdown]
# # Model 6

# %%
plt.plot(df["Date"], df["Actuals"])
plt.plot(df["Date"], df["Model 6"]) 
plt.ylabel("S&P 500 Realized Volatility")
plt.legend(['Actuals', 'Forecasts'])
